# %%
# Set up environment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
reps = pd.read_excel('2020 project english.xlsx')
reps.head()
# Out:
#    Report Period   Group Name        Agent Name  Attuid  Percent Calls Noted  \
# 0  201901-201911  San Antonio      AARON ALONZO  AA134U               0.8705
# 1  201901-201911  San Antonio   AUDREY GUERRERO  AD3388               0.8764
# 2  201901-201911  San Antonio  ANDREA GILLESPIE  AG592V               0.8644
# 3  201901-201911  San Antonio      ANGELA LEWIS  AL6947               0.8101
# 4  201901-201911  San Antonio      ANNA RAMIREZ  AR045T               0.8626
#
#    Convenience Fee Waivers Scheduled Open Hours  Schedule Adherence  \
# 0                   0.5899  1900-02-20 16:44:00              0.9344
# 1                   0.2831  1900-02-25 23:19:00              0.9527
# 2                   0.3116  1900-02-21 08:37:00              0.9194
# 3                   0.4207  1900-02-21 07:59:00              0.9632
# 4                   0.4163  1900-02-25 03:59:00              0.9596
#
#    Availability  Total Vs Total - eTRACS  ...  Inbound AHT - ENG  \
# ...

# %%
reps.dtypes
# Out:
# Report Period                           object
# Group Name                              object
# Agent Name                              object
# Attuid                                  object
# Percent Calls Noted                    float64
# Convenience Fee Waivers                float64
# Scheduled Open Hours            datetime64[ns]
# Schedule Adherence                     float64
# Availability                           float64
# Total Vs Total - eTRACS                float64
# Immediate Vs Total - eTRACS            float64
# Transfers                              float64
# Inbound AHT - ENG                      float64
# Calls Answered - ENG                     int64
# Calls Answered - SPA                   float64
# Inbound AHT - SPA                      float64
# Inbound AHT                            float64
# Call Tracker Compliance                float64
# PCF Work Review                        float64
# Cust Exp - Call Observations           float64
# ...
